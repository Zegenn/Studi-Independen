# %% [markdown]
# # Self Learning

# %% [markdown]
# 1. Apa yang dimaksud dengan Virtual Environment?
#    Jawab:
#    Wadah/Alat yang membantu untuk membuat atau mengolah setiap proyek Phyton.
#
# 2. Sebutkan Tools untuk membuat Virtual Environment!
#    Jawab:
#    - Pipenv
#    - Conda
#    - Poetry
#    - Anaconda Navigator

# %% [markdown]
# ## **Menggunakan Environment base**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Menggunakan Environment SnakeCage**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
from gtts import gTTS
from audioplayer import AudioPlayer

congrats = 'Selamat, Anda telah berhasil mengelola sebuah environment!'
language = 'id'
file_name = 'congratulations.mp3'

tts = gTTS(text=congrats, lang=language)
tts.save(file.name)
AudioPlayer(file_name).play(block=True)
print(congrats)

# %% [markdown]
# Kesimpulannya, Environment SnakeCage berhasil menjalankan program ekstensi .py dan tidak mempengaruhi environment lain.
